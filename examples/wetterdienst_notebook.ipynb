# %% [markdown]
# # wetterdienst - A basic notebook example

# %%
#!pip install wetterdienst

# %% [markdown]
# ## Import modules necessary for general functioning

# %%
from pprint import pprint

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import polars as pl
from matplotlib import colormaps

from wetterdienst import Settings
from wetterdienst.provider.dwd.observation import (
    DwdObservationDataset,
    DwdObservationParameter,
    DwdObservationPeriod,
    DwdObservationRequest,
    DwdObservationResolution,
)

# %%
# %matplotlib inline

# %% [markdown]
# Wetterdienst default settings

# %%
# don't display real cache_dir, which might contain sensible information
settings = Settings.default().to_dict()
settings.update({"cache_dir": "abc"})
settings
# Out:
# {'cache_disable': False,
#  'cache_dir': 'abc',
#  'fsspec_client_kwargs': {},
#  'ts_humanize': True,
#  'ts_shape': 'long',
#  'ts_si_units': True,
#  'ts_skip_empty': False,
#  'ts_skip_threshold': 0.95,
#  'ts_skip_criteria': 'min',
#  'ts_dropna': False,
#  'ts_interpolation_station_distance': {'default': 40.0,
#   'precipitation_height': 20.0},
#  'ts_interpolation_use_nearby_station_distance': 1}

# %% [markdown]
# ## Which parameters are available?

# %% [markdown]
# All available parameters

# %%
pprint(DwdObservationRequest.discover())
# Out:
# {'annual': {'cloud_cover_total': {'origin': '1/8', 'si': 'pct'},
#             'count_weather_type_dew': {'origin': '-', 'si': '-'},
#             'count_weather_type_fog': {'origin': '-', 'si': '-'},
#             'count_weather_type_glaze': {'origin': '-', 'si': '-'},
#             'count_weather_type_hail': {'origin': '-', 'si': '-'},
#             'count_weather_type_sleet': {'origin': '-', 'si': '-'},
#             'count_weather_type_storm_stormier_wind': {'origin': '-',
#                                                        'si': '-'},
#             'count_weather_type_storm_strong_wind': {'origin': '-', 'si': '-'},
#             'count_weather_type_thunder': {'origin': '-', 'si': '-'},
#             'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#             'precipitation_height_max': {'origin': 'mm', 'si': 'kg / m ** 2'},
#             'snow_depth': {'origin': 'cm', 'si': 'm'},
#             'snow_depth_new': {'origin': 'cm', 'si': 'm'},
#             'sunshine_duration': {'origin': 'h', 'si': 's'},
#             'temperature_air_max_200': {'origin': '°C', 'si': 'K'},
#             'temperature_air_max_200_mean': {'origin': '°C', 'si': 'K'},
#             'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#             'temperature_air_min_200': {'origin': '°C', 'si': 'K'},
#             'temperature_air_min_200_mean': {'origin': '°C', 'si': 'K'},
#             'wind_force_beaufort': {'origin': 'bft', 'si': 'bft'},
#             'wind_gust_max': {'origin': 'm / s', 'si': 'm / s'}},
#  'daily': {'cloud_cover_total': {'origin': '1/8', 'si': 'pct'},
#            'count_weather_type_dew': {'origin': '-', 'si': '-'},
#            'count_weather_type_fog': {'origin': '-', 'si': '-'},
#            'count_weather_type_glaze': {'origin': '-', 'si': '-'},
#            'count_weather_type_hail': {'origin': '-', 'si': '-'},
#            'count_weather_type_ripe': {'origin': '-', 'si': '-'},
#            'count_weather_type_sleet': {'origin': '-', 'si': '-'},
#            'count_weather_type_storm_stormier_wind': {'origin': '-', 'si': '-'},
#            'count_weather_type_storm_strong_wind': {'origin': '-', 'si': '-'},
#            'count_weather_type_thunder': {'origin': '-', 'si': '-'},
#            'humidity': {'origin': 'pct', 'si': 'pct'},
#            'precipitation_form': {'origin': '-', 'si': '-'},
#            'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#            'pressure_air_site': {'origin': 'hPa', 'si': 'Pa'},
#            'pressure_vapor': {'origin': 'hPa', 'si': 'Pa'},
#            'radiation_global': {'origin': 'J / cm ** 2', 'si': 'J / m ** 2'},
#            'radiation_sky_long_wave': {'origin': 'J / cm ** 2',
#                                        'si': 'J / m ** 2'},
#            'radiation_sky_short_wave_diffuse': {'origin': 'J / cm ** 2',
#                                                 'si': 'J / m ** 2'},
#            'snow_depth': {'origin': 'cm', 'si': 'm'},
#            'snow_depth_excelled': {'origin': 'cm', 'si': 'm'},
#            'snow_depth_new': {'origin': 'cm', 'si': 'm'},
#            'sunshine_duration': {'origin': 'h', 'si': 's'},
#            'temperature_air_max_200': {'origin': '°C', 'si': 'K'},
#            'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#            'temperature_air_min_005': {'origin': '°C', 'si': 'K'},
#            'temperature_air_min_200': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_002': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_005': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_010': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_020': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_050': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_100': {'origin': '°C', 'si': 'K'},
#            'water_equivalent_snow_depth': {'origin': 'mm', 'si': 'kg / m ** 2'},
#            'water_equivalent_snow_depth_excelled': {'origin': 'mm',
#                                                     'si': 'kg / m ** 2'},
#            'wind_gust_max': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_speed': {'origin': 'm / s', 'si': 'm / s'}},
#  'hourly': {'cloud_cover_layer1': {'origin': '1/8', 'si': 'pct'},
#             'cloud_cover_layer2': {'origin': '1/8', 'si': 'pct'},
#             'cloud_cover_layer3': {'origin': '1/8', 'si': 'pct'},
#             'cloud_cover_layer4': {'origin': '1/8', 'si': 'pct'},
#             'cloud_cover_total': {'origin': '1/8', 'si': 'pct'},
#             'cloud_cover_total_index': {'origin': '-', 'si': '-'},
#             'cloud_height_layer1': {'origin': 'm', 'si': 'm'},
#             'cloud_height_layer2': {'origin': 'm', 'si': 'm'},
#             'cloud_height_layer3': {'origin': 'm', 'si': 'm'},
#             'cloud_height_layer4': {'origin': 'm', 'si': 'm'},
#             'cloud_type_layer1': {'origin': '-', 'si': '-'},
#             'cloud_type_layer2': {'origin': '-', 'si': '-'},
#             'cloud_type_layer3': {'origin': '-', 'si': '-'},
#             'cloud_type_layer4': {'origin': '-', 'si': '-'},
#             'humidity': {'origin': 'pct', 'si': 'pct'},
#             'humidity_absolute': {'origin': '-', 'si': '-'},
#             'precipitation_form': {'origin': '-', 'si': '-'},
#             'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#             'precipitation_index': {'origin': '-', 'si': '-'},
#             'pressure_air_sea_level': {'origin': 'hPa', 'si': 'Pa'},
#             'pressure_air_site': {'origin': 'hPa', 'si': 'Pa'},
#             'pressure_vapor': {'origin': 'hPa', 'si': 'Pa'},
#             'radiation_global': {'origin': 'J / cm ** 2', 'si': 'J / m ** 2'},
#             'radiation_sky_long_wave': {'origin': 'J / cm ** 2',
#                                         'si': 'J / m ** 2'},
#             'radiation_sky_short_wave_diffuse': {'origin': 'J / cm ** 2',
#                                                  'si': 'J / m ** 2'},
#             'sun_zenith_angle': {'origin': 'deg', 'si': 'deg'},
#             'sunshine_duration': {'origin': 'min', 'si': 's'},
#             'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#             'temperature_dew_point_mean_200': {'origin': '°C', 'si': 'K'},
#             'temperature_soil_mean_002': {'origin': '°C', 'si': 'K'},
#             'temperature_soil_mean_005': {'origin': '°C', 'si': 'K'},
#             'temperature_soil_mean_010': {'origin': '°C', 'si': 'K'},
#             'temperature_soil_mean_020': {'origin': '°C', 'si': 'K'},
#             'temperature_soil_mean_050': {'origin': '°C', 'si': 'K'},
#             'temperature_soil_mean_100': {'origin': '°C', 'si': 'K'},
#             'temperature_wet_mean_200': {'origin': '°C', 'si': 'K'},
#             'visibility_range': {'origin': 'm', 'si': 'm'},
#             'visibility_range_index': {'origin': '-', 'si': '-'},
#             'weather': {'origin': '-', 'si': '-'},
#             'wind_direction': {'origin': 'deg', 'si': 'deg'},
#             'wind_gust_max': {'origin': 'm / s', 'si': 'm / s'},
#             'wind_speed': {'origin': 'm / s', 'si': 'm / s'}},
#  'minute_1': {'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#               'precipitation_height_droplet': {'origin': 'mm',
#                                                'si': 'kg / m ** 2'},
#               'precipitation_height_rocker': {'origin': 'mm',
#                                               'si': 'kg / m ** 2'},
#               'precipitation_index': {'origin': '-', 'si': '-'}},
#  'minute_10': {'humidity': {'origin': 'pct', 'si': 'pct'},
#                'precipitation_duration': {'origin': 'min', 'si': 's'},
#                'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#                'precipitation_index': {'origin': '-', 'si': '-'},
#                'pressure_air_site': {'origin': 'hPa', 'si': 'Pa'},
#                'radiation_global': {'origin': 'J / cm ** 2',
#                                     'si': 'J / m ** 2'},
#                'radiation_sky_long_wave': {'origin': 'J / cm ** 2',
#                                            'si': 'J / m ** 2'},
#                'radiation_sky_short_wave_diffuse': {'origin': 'J / cm ** 2',
#                                                     'si': 'J / m ** 2'},
#                'sunshine_duration': {'origin': 'h', 'si': 's'},
#                'temperature_air_max_005': {'origin': '°C', 'si': 'K'},
#                'temperature_air_max_200': {'origin': '°C', 'si': 'K'},
#                'temperature_air_mean_005': {'origin': '°C', 'si': 'K'},
#                'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#                'temperature_air_min_005': {'origin': '°C', 'si': 'K'},
#                'temperature_air_min_200': {'origin': '°C', 'si': 'K'},
#                'temperature_dew_point_mean_200': {'origin': '°C', 'si': 'K'},
#                'wind_direction': {'origin': 'deg', 'si': 'deg'},
#                'wind_direction_gust_max': {'origin': 'deg', 'si': 'deg'},
#                'wind_gust_max': {'origin': 'm / s', 'si': 'm / s'},
#                'wind_speed': {'origin': 'm / s', 'si': 'm / s'},
#                'wind_speed_min': {'origin': 'm / s', 'si': 'm / s'},
#                'wind_speed_rolling_mean_max': {'origin': 'm / s',
#                                                'si': 'm / s'}},
#  'minute_5': {'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#               'precipitation_height_droplet': {'origin': 'mm',
#                                                'si': 'kg / m ** 2'},
#               'precipitation_height_rocker': {'origin': 'mm',
#                                               'si': 'kg / m ** 2'},
#               'precipitation_index': {'origin': '-', 'si': '-'}},
#  'monthly': {'cloud_cover_total': {'origin': '1/8', 'si': 'pct'},
#              'count_weather_type_dew': {'origin': '-', 'si': '-'},
#              'count_weather_type_fog': {'origin': '-', 'si': '-'},
#              'count_weather_type_glaze': {'origin': '-', 'si': '-'},
#              'count_weather_type_hail': {'origin': '-', 'si': '-'},
#              'count_weather_type_sleet': {'origin': '-', 'si': '-'},
#              'count_weather_type_storm_stormier_wind': {'origin': '-',
#                                                         'si': '-'},
#              'count_weather_type_storm_strong_wind': {'origin': '-', 'si': '-'},
#              'count_weather_type_thunder': {'origin': '-', 'si': '-'},
#              'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#              'precipitation_height_max': {'origin': 'mm', 'si': 'kg / m ** 2'},
#              'snow_depth': {'origin': 'cm', 'si': 'm'},
#              'snow_depth_new': {'origin': 'cm', 'si': 'm'},
#              'sunshine_duration': {'origin': 'h', 'si': 's'},
#              'temperature_air_max_200': {'origin': '°C', 'si': 'K'},
#              'temperature_air_max_200_mean': {'origin': '°C', 'si': 'K'},
#              'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#              'temperature_air_min_200': {'origin': '°C', 'si': 'K'},
#              'temperature_air_min_200_mean': {'origin': '°C', 'si': 'K'},
#              'wind_force_beaufort': {'origin': 'bft', 'si': 'bft'},
#              'wind_gust_max': {'origin': 'm / s', 'si': 'm / s'}},
#  'subdaily': {'cloud_cover_total': {'origin': '1/8', 'si': 'pct'},
#               'cloud_density': {'origin': '-', 'si': '-'},
#               'humidity': {'origin': 'pct', 'si': 'pct'},
#               'pressure_air_site': {'origin': 'hPa', 'si': 'Pa'},
#               'pressure_vapor': {'origin': 'hPa', 'si': 'Pa'},
#               'temperature_air_mean_005': {'origin': '°C', 'si': 'K'},
#               'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#               'temperature_soil_mean_005': {'origin': '°C', 'si': 'K'},
#               'visibility_range': {'origin': 'm', 'si': 'm'},
#               'wind_direction': {'origin': 'deg', 'si': 'deg'},
#               'wind_force_beaufort': {'origin': 'bft', 'si': 'bft'},
#               'wind_gust_max_last_3h': {'origin': 'm / s', 'si': 'm / s'},
#               'wind_gust_max_last_6h': {'origin': 'm / s', 'si': 'm / s'}}}

# %% [markdown]
# Selection of daily data

# %%
pprint(DwdObservationRequest.discover(resolution=DwdObservationResolution.DAILY))
# Out:
# {'daily': {'cloud_cover_total': {'origin': '1/8', 'si': 'pct'},
#            'count_weather_type_dew': {'origin': '-', 'si': '-'},
#            'count_weather_type_fog': {'origin': '-', 'si': '-'},
#            'count_weather_type_glaze': {'origin': '-', 'si': '-'},
#            'count_weather_type_hail': {'origin': '-', 'si': '-'},
#            'count_weather_type_ripe': {'origin': '-', 'si': '-'},
#            'count_weather_type_sleet': {'origin': '-', 'si': '-'},
#            'count_weather_type_storm_stormier_wind': {'origin': '-', 'si': '-'},
#            'count_weather_type_storm_strong_wind': {'origin': '-', 'si': '-'},
#            'count_weather_type_thunder': {'origin': '-', 'si': '-'},
#            'humidity': {'origin': 'pct', 'si': 'pct'},
#            'precipitation_form': {'origin': '-', 'si': '-'},
#            'precipitation_height': {'origin': 'mm', 'si': 'kg / m ** 2'},
#            'pressure_air_site': {'origin': 'hPa', 'si': 'Pa'},
#            'pressure_vapor': {'origin': 'hPa', 'si': 'Pa'},
#            'radiation_global': {'origin': 'J / cm ** 2', 'si': 'J / m ** 2'},
#            'radiation_sky_long_wave': {'origin': 'J / cm ** 2',
#                                        'si': 'J / m ** 2'},
#            'radiation_sky_short_wave_diffuse': {'origin': 'J / cm ** 2',
#                                                 'si': 'J / m ** 2'},
#            'snow_depth': {'origin': 'cm', 'si': 'm'},
#            'snow_depth_excelled': {'origin': 'cm', 'si': 'm'},
#            'snow_depth_new': {'origin': 'cm', 'si': 'm'},
#            'sunshine_duration': {'origin': 'h', 'si': 's'},
#            'temperature_air_max_200': {'origin': '°C', 'si': 'K'},
#            'temperature_air_mean_200': {'origin': '°C', 'si': 'K'},
#            'temperature_air_min_005': {'origin': '°C', 'si': 'K'},
#            'temperature_air_min_200': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_002': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_005': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_010': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_020': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_050': {'origin': '°C', 'si': 'K'},
#            'temperature_soil_mean_100': {'origin': '°C', 'si': 'K'},
#            'water_equivalent_snow_depth': {'origin': 'mm', 'si': 'kg / m ** 2'},
#            'water_equivalent_snow_depth_excelled': {'origin': 'mm',
#                                                     'si': 'kg / m ** 2'},
#            'wind_gust_max': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_speed': {'origin': 'm / s', 'si': 'm / s'}}}

# %% [markdown]
# ## List of historical daily precipitation stations of DWD (Germany)

# %%
request = DwdObservationRequest(
    parameter=DwdObservationDataset.PRECIPITATION_MORE,
    resolution=DwdObservationResolution.DAILY,
    period=DwdObservationPeriod.HISTORICAL,
).all()
request.df.head()
# Out:
# shape: (5, 8)
# ┌────────────┬─────────────┬─────────────┬──────────┬───────────┬────────┬────────────┬────────────┐
# │ station_id ┆ start_date  ┆ end_date    ┆ latitude ┆ longitude ┆ height ┆ name       ┆ state      │
# │ ---        ┆ ---         ┆ ---         ┆ ---      ┆ ---       ┆ ---    ┆ ---        ┆ ---        │
# │ str        ┆ datetime[μs ┆ datetime[μs ┆ f64      ┆ f64       ┆ f64    ┆ str        ┆ str        │
# │            ┆ , UTC]      ┆ , UTC]      ┆          ┆           ┆        ┆            ┆            │
# ╞════════════╪═════════════╪═════════════╪══════════╪═══════════╪════════╪════════════╪════════════╡
# │ 00001      ┆ 1912-01-01  ┆ 1986-06-30  ┆ 47.8413  ┆ 8.8493    ┆ 478.0  ┆ Aach       ┆ Baden-Würt │
# │            ┆ 00:00:00    ┆ 00:00:00    ┆          ┆           ┆        ┆            ┆ temberg    │
# │            ┆ UTC         ┆ UTC         ┆          ┆           ┆        ┆            ┆            │
# │ 00002      ┆ 1951-01-01  ┆ 2006-12-31  ┆ 50.8066  ┆ 6.0996    ┆ 138.0  ┆ Aachen (Kl ┆ Nordrhein- │
# │            ┆ 00:00:00    ┆ 00:00:00    ┆          ┆           ┆        ┆ äranlage)  ┆ Westfalen  │
# │            ┆ UTC         ┆ UTC         ┆          ┆           ┆        ┆            ┆            │
# │ 00003      ┆ 1891-01-01  ┆ 2011-03-31  ┆ 50.7827  ┆ 6.0941    ┆ 202.0  ┆ Aachen     ┆ Nordrhein- │
# │            ┆ 00:00:00    ┆ 00:00:00    ┆          ┆           ┆        ┆            ┆ Westfalen  │
# │            ┆ UTC         ┆ UTC         ┆          ┆           ┆        ┆            ┆            │
# │ 00004      ┆ 1951-01-01  ┆ 1979-10-31  ┆ 50.7683  ┆ 6.1207    ┆ 243.0  ┆ Aachen-Bra ┆ Nordrhein- │
# │            ┆ 00:00:00    ┆ 00:00:00    ┆          ┆           ┆        ┆ nd         ┆ Westfalen  │
# │            ┆ UTC         ┆ UTC         ┆          ┆           ┆        ┆            ┆            │
# │ 00006      ┆ 1982-11-01  ┆ 2023-12-27  ┆ 48.8361  ┆ 10.0598   ┆ 455.0  ┆ Aalen-Unte ┆ Baden-Würt │
# │            ┆ 00:00:00    ┆ 00:00:00    ┆          ┆           ┆        ┆ rrombach   ┆ temberg    │
# │            ┆ UTC         ┆ UTC         ┆          ┆           ┆        ┆            ┆            │
# └────────────┴─────────────┴─────────────┴──────────┴───────────┴────────┴────────────┴────────────┘

# %% [markdown]
# Number of stations with available data

# %%
request.df.shape
# Out:
# (5733, 8)

# %% [markdown]
# ## Map of historical daily precipitation stations of DWD (Germany)

# %%
cmap = colormaps.get_cmap("viridis")
bounds = np.quantile(request.df.get_column("height"), [0, 0.25, 0.5, 0.75, 1])
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
fig, ax = plt.subplots(figsize=(10, 10), tight_layout=True)
plot = request.df.to_pandas().plot.scatter(x="longitude", y="latitude", c="height", cmap=cmap, norm=norm, ax=ax)
title = "Map of daily precipitation stations in Germany"
plot.set_title(title)
plt.show()

# %% [markdown]
# ## Get data for daily precipitation station - Dresden Klotzsche (1048)

# %%
values = (
    DwdObservationRequest(
        parameter=DwdObservationDataset.PRECIPITATION_MORE,
        resolution=DwdObservationResolution.DAILY,
        period=DwdObservationPeriod.HISTORICAL,
    )
    .filter_by_station_id(station_id=[1048])
    .values.all()
    .df
)
values.drop_nulls().head()
# Out:
# shape: (5, 6)
# ┌────────────┬────────────────────┬────────────────────┬─────────────────────────┬───────┬─────────┐
# │ station_id ┆ dataset            ┆ parameter          ┆ date                    ┆ value ┆ quality │
# │ ---        ┆ ---                ┆ ---                ┆ ---                     ┆ ---   ┆ ---     │
# │ str        ┆ str                ┆ str                ┆ datetime[μs, UTC]       ┆ f64   ┆ f64     │
# ╞════════════╪════════════════════╪════════════════════╪═════════════════════════╪═══════╪═════════╡
# │ 01048      ┆ precipitation_more ┆ precipitation_form ┆ 1926-04-25 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# │ 01048      ┆ precipitation_more ┆ precipitation_form ┆ 1926-04-26 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# │ 01048      ┆ precipitation_more ┆ precipitation_form ┆ 1926-04-27 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# │ 01048      ┆ precipitation_more ┆ precipitation_form ┆ 1926-04-28 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# │ 01048      ┆ precipitation_more ┆ precipitation_form ┆ 1926-04-29 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# └────────────┴────────────────────┴────────────────────┴─────────────────────────┴───────┴─────────┘

# %% [markdown]
# ## Get data for daily precipitation and temperature (tmin, tmean, tmax) for station - Dresden Klotzsche (1048)

# %%
parameters = [
    DwdObservationParameter.DAILY.TEMPERATURE_AIR_MEAN_200,
    DwdObservationParameter.DAILY.TEMPERATURE_AIR_MAX_200,
    DwdObservationParameter.DAILY.TEMPERATURE_AIR_MIN_200,
    DwdObservationParameter.DAILY.PRECIPITATION_HEIGHT,
]
values = (
    DwdObservationRequest(
        parameter=parameters, resolution=DwdObservationResolution.DAILY, period=DwdObservationPeriod.HISTORICAL
    )
    .filter_by_station_id(station_id=(1048,))
    .values.all()
)
values.df.drop_nulls().head()
# Out:
# shape: (5, 6)
# ┌────────────┬─────────────────┬──────────────────────┬─────────────────────────┬───────┬─────────┐
# │ station_id ┆ dataset         ┆ parameter            ┆ date                    ┆ value ┆ quality │
# │ ---        ┆ ---             ┆ ---                  ┆ ---                     ┆ ---   ┆ ---     │
# │ str        ┆ str             ┆ str                  ┆ datetime[μs, UTC]       ┆ f64   ┆ f64     │
# ╞════════════╪═════════════════╪══════════════════════╪═════════════════════════╪═══════╪═════════╡
# │ 01048      ┆ climate_summary ┆ precipitation_height ┆ 1934-01-01 00:00:00 UTC ┆ 0.2   ┆ 1.0     │
# │ 01048      ┆ climate_summary ┆ precipitation_height ┆ 1934-01-02 00:00:00 UTC ┆ 0.1   ┆ 1.0     │
# │ 01048      ┆ climate_summary ┆ precipitation_height ┆ 1934-01-03 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# │ 01048      ┆ climate_summary ┆ precipitation_height ┆ 1934-01-04 00:00:00 UTC ┆ 0.0   ┆ 1.0     │
# │ 01048      ┆ climate_summary ┆ precipitation_height ┆ 1934-01-05 00:00:00 UTC ┆ 10.1  ┆ 1.0     │
# └────────────┴─────────────────┴──────────────────────┴─────────────────────────┴───────┴─────────┘

# %% [markdown]
# ## Aggregate to annual values

# %%
data = []
for (parameter,), group in values.df.groupby([pl.col("parameter")], maintain_order=True):
    if parameter == "precipitation_height":
        agg_df = group.groupby(pl.col("date").dt.year(), maintain_order=True).agg(
            pl.when(pl.col("value").is_not_null().sum() > 330).then(pl.col("value").sum())
        )
    else:
        agg_df = group.groupby(pl.col("date").dt.year(), maintain_order=True).agg([pl.col("value").mean()])
    agg_df = agg_df.select(
        pl.lit(parameter).alias("parameter"),
        pl.col("date").cast(pl.Utf8).str.to_datetime("%Y"),
        pl.col("value"),
    )
    data.append(agg_df)
df_annual = pl.concat(data)
df_annual
# Out:
# /var/folders/78/nkfpnwgn71sgt9ql2g124tv40000gn/T/ipykernel_19277/3531731956.py:2: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   for (parameter,), group in values.df.groupby([pl.col("parameter")], maintain_order=True):
# /var/folders/78/nkfpnwgn71sgt9ql2g124tv40000gn/T/ipykernel_19277/3531731956.py:4: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   agg_df = group.groupby(pl.col("date").dt.year(), maintain_order=True).agg(
# /var/folders/78/nkfpnwgn71sgt9ql2g124tv40000gn/T/ipykernel_19277/3531731956.py:8: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   agg_df = group.groupby(pl.col("date").dt.year(), maintain_order=True).agg([pl.col("value").mean()])
# shape: (300, 3)
# ┌─────────────────────────┬─────────────────────┬────────────┐
# │ parameter               ┆ date                ┆ value      │
# │ ---                     ┆ ---                 ┆ ---        │
# │ str                     ┆ datetime[μs]        ┆ f64        │
# ╞═════════════════════════╪═════════════════════╪════════════╡
# │ precipitation_height    ┆ 1934-01-01 00:00:00 ┆ 675.6      │
# │ precipitation_height    ┆ 1935-01-01 00:00:00 ┆ 643.1      │
# │ precipitation_height    ┆ 1936-01-01 00:00:00 ┆ 555.2      │
# │ precipitation_height    ┆ 1937-01-01 00:00:00 ┆ 793.7      │
# │ …                       ┆ …                   ┆ …          │
# │ temperature_air_min_200 ┆ 2019-01-01 00:00:00 ┆ 279.958493 │
# │ temperature_air_min_200 ┆ 2020-01-01 00:00:00 ┆ 279.723497 │
# │ temperature_air_min_200 ┆ 2021-01-01 00:00:00 ┆ 278.934658 │
# │ temperature_air_min_200 ┆ 2022-01-01 00:00:00 ┆ 279.596575 │
# └─────────────────────────┴─────────────────────┴────────────┘

# %% [markdown]
# ## Create some plots for the data

# %%
cmap = plt.get_cmap("viridis", 4)
colors = cmap.colors
fig, axes = plt.subplots(nrows=len(parameters), tight_layout=True, sharex=True, figsize=(10, 10))  #
for (parameter, daily), (_, annual), ax, color in zip(
    values.df.groupby("parameter", maintain_order=True),
    df_annual.groupby("parameter", maintain_order=True),
    axes,
    colors,
):
    if parameter == "precipitation_height":
        ax2 = ax.twinx()
    else:
        ax2 = ax
    daily.to_pandas().plot(x="date", y="value", label=parameter, alpha=0.75, ax=ax, c=color, legend=False)
    annual.to_pandas().plot(
        x="date", y="value", kind="line", label=f"annual({parameter})", alpha=0.75, ax=ax2, c="black", legend=False
    )
    ax.legend(loc=0)
    if ax != ax2:
        ax2.legend(loc=3)
plt.suptitle("Temperature and precipitation time series of Dresden, Germany", y=1.01)
plt.show()
# Out:
# /var/folders/78/nkfpnwgn71sgt9ql2g124tv40000gn/T/ipykernel_19277/3488620726.py:5: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   values.df.groupby("parameter", maintain_order=True),
# /var/folders/78/nkfpnwgn71sgt9ql2g124tv40000gn/T/ipykernel_19277/3488620726.py:6: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
#   df_annual.groupby("parameter", maintain_order=True),

# %% [markdown]
# ## Find a station

# %%
request = DwdObservationRequest(
    parameter=DwdObservationParameter.DAILY.CLIMATE_SUMMARY.TEMPERATURE_AIR_MEAN_200,
    resolution=DwdObservationResolution.DAILY,
    period=DwdObservationPeriod.HISTORICAL,
    start_date="1930-01-01",
    end_date="1970-01-01",
)
# Out:
# start_date and end_date filtering limited to defined periods [<Period.HISTORICAL: 'historical'>]

# %%
request.filter_by_rank((51.05089, 13.73832), 5).df
# Out:
# shape: (1_246, 9)
# ┌────────────┬────────────┬────────────┬──────────┬───┬────────┬───────────┬───────────┬───────────┐
# │ station_id ┆ start_date ┆ end_date   ┆ latitude ┆ … ┆ height ┆ name      ┆ state     ┆ distance  │
# │ ---        ┆ ---        ┆ ---        ┆ ---      ┆   ┆ ---    ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ datetime[μ ┆ datetime[μ ┆ f64      ┆   ┆ f64    ┆ str       ┆ str       ┆ f64       │
# │            ┆ s, UTC]    ┆ s, UTC]    ┆          ┆   ┆        ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪══════════╪═══╪════════╪═══════════╪═══════════╪═══════════╡
# │ 01047      ┆ 1828-01-01 ┆ 1915-12-31 ┆ 51.0557  ┆ … ┆ 112.0  ┆ Dresden   ┆ Sachsen   ┆ 0.932013  │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ (Mitte)   ┆           ┆           │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ 01051      ┆ 1936-01-01 ┆ 2023-10-03 ┆ 51.0249  ┆ … ┆ 119.0  ┆ Dresden-S ┆ Sachsen   ┆ 3.863854  │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ trehlen   ┆           ┆           │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ 01050      ┆ 1949-01-01 ┆ 2023-12-27 ┆ 51.0221  ┆ … ┆ 112.0  ┆ Dresden-H ┆ Sachsen   ┆ 8.245925  │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ osterwitz ┆           ┆           │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ 01048      ┆ 1934-01-01 ┆ 2023-12-27 ┆ 51.1278  ┆ … ┆ 228.0  ┆ Dresden-K ┆ Sachsen   ┆ 8.624522  │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ lotzsche  ┆           ┆           │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …        ┆ … ┆ …      ┆ …         ┆ …         ┆ …         │
# │ 04175      ┆ 1953-09-01 ┆ 2023-12-27 ┆ 47.559   ┆ … ┆ 283.0  ┆ Rheinfeld ┆ Baden-Wür ┆ 580.93561 │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ en        ┆ ttemberg  ┆ 3         │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ 01169      ┆ 1976-02-01 ┆ 1999-09-30 ┆ 47.6288  ┆ … ┆ 264.0  ┆ Eimelding ┆ Baden-Wür ┆ 585.18047 │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ en        ┆ ttemberg  ┆ 6         │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ 01228      ┆ 2000-07-01 ┆ 2023-12-27 ┆ 54.1651  ┆ … ┆ 0.0    ┆ UFS TW    ┆ Hamburg   ┆ 607.02872 │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ Ems       ┆           ┆ 8         │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# │ 13904      ┆ 2008-09-28 ┆ 2008-12-30 ┆ 55.0     ┆ … ┆ 3.0    ┆ Nordseebo ┆ Hamburg   ┆ 661.25922 │
# │            ┆ 00:00:00   ┆ 00:00:00   ┆          ┆   ┆        ┆ je 2      ┆           ┆ 7         │
# │            ┆ UTC        ┆ UTC        ┆          ┆   ┆        ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴──────────┴───┴────────┴───────────┴───────────┴───────────┘

# %%
request.filter_by_distance((51.05089, 13.73832), 20).df
# Out:
# shape: (6, 9)
# ┌────────────┬─────────────┬────────────┬──────────┬───┬────────┬────────────┬─────────┬───────────┐
# │ station_id ┆ start_date  ┆ end_date   ┆ latitude ┆ … ┆ height ┆ name       ┆ state   ┆ distance  │
# │ ---        ┆ ---         ┆ ---        ┆ ---      ┆   ┆ ---    ┆ ---        ┆ ---     ┆ ---       │
# │ str        ┆ datetime[μs ┆ datetime[μ ┆ f64      ┆   ┆ f64    ┆ str        ┆ str     ┆ f64       │
# │            ┆ , UTC]      ┆ s, UTC]    ┆          ┆   ┆        ┆            ┆         ┆           │
# ╞════════════╪═════════════╪════════════╪══════════╪═══╪════════╪════════════╪═════════╪═══════════╡
# │ 01047      ┆ 1828-01-01  ┆ 1915-12-31 ┆ 51.0557  ┆ … ┆ 112.0  ┆ Dresden    ┆ Sachsen ┆ 0.932013  │
# │            ┆ 00:00:00    ┆ 00:00:00   ┆          ┆   ┆        ┆ (Mitte)    ┆         ┆           │
# │            ┆ UTC         ┆ UTC        ┆          ┆   ┆        ┆            ┆         ┆           │
# │ 01051      ┆ 1936-01-01  ┆ 2023-10-03 ┆ 51.0249  ┆ … ┆ 119.0  ┆ Dresden-St ┆ Sachsen ┆ 3.863854  │
# │            ┆ 00:00:00    ┆ 00:00:00   ┆          ┆   ┆        ┆ rehlen     ┆         ┆           │
# │            ┆ UTC         ┆ UTC        ┆          ┆   ┆        ┆            ┆         ┆           │
# │ 01050      ┆ 1949-01-01  ┆ 2023-12-27 ┆ 51.0221  ┆ … ┆ 112.0  ┆ Dresden-Ho ┆ Sachsen ┆ 8.245925  │
# │            ┆ 00:00:00    ┆ 00:00:00   ┆          ┆   ┆        ┆ sterwitz   ┆         ┆           │
# │            ┆ UTC         ┆ UTC        ┆          ┆   ┆        ┆            ┆         ┆           │
# │ 01048      ┆ 1934-01-01  ┆ 2023-12-27 ┆ 51.1278  ┆ … ┆ 228.0  ┆ Dresden-Kl ┆ Sachsen ┆ 8.624522  │
# │            ┆ 00:00:00    ┆ 00:00:00   ┆          ┆   ┆        ┆ otzsche    ┆         ┆           │
# │            ┆ UTC         ┆ UTC        ┆          ┆   ┆        ┆            ┆         ┆           │
# │ 05282      ┆ 1917-01-01  ┆ 1974-06-30 ┆ 51.1197  ┆ … ┆ 246.0  ┆ Wahnsdorf  ┆ Sachsen ┆ 8.858692  │
# │            ┆ 00:00:00    ┆ 00:00:00   ┆          ┆   ┆        ┆ bei        ┆         ┆           │
# │            ┆ UTC         ┆ UTC        ┆          ┆   ┆        ┆ Dresden    ┆         ┆           │
# │ 00991      ┆ 1954-09-01  ┆ 2023-12-27 ┆ 50.9116  ┆ … ┆ 359.0  ┆ Dippoldisw ┆ Sachsen ┆ 15.626528 │
# │            ┆ 00:00:00    ┆ 00:00:00   ┆          ┆   ┆        ┆ alde-Reinb ┆         ┆           │
# │            ┆ UTC         ┆ UTC        ┆          ┆   ┆        ┆ erg        ┆         ┆           │
# └────────────┴─────────────┴────────────┴──────────┴───┴────────┴────────────┴─────────┴───────────┘

# %%
request.filter_by_station_id("1048").df
# Out:
# shape: (1, 8)
# ┌────────────┬──────────────┬──────────────┬──────────┬───────────┬────────┬─────────────┬─────────┐
# │ station_id ┆ start_date   ┆ end_date     ┆ latitude ┆ longitude ┆ height ┆ name        ┆ state   │
# │ ---        ┆ ---          ┆ ---          ┆ ---      ┆ ---       ┆ ---    ┆ ---         ┆ ---     │
# │ str        ┆ datetime[μs, ┆ datetime[μs, ┆ f64      ┆ f64       ┆ f64    ┆ str         ┆ str     │
# │            ┆ UTC]         ┆ UTC]         ┆          ┆           ┆        ┆             ┆         │
# ╞════════════╪══════════════╪══════════════╪══════════╪═══════════╪════════╪═════════════╪═════════╡
# │ 01048      ┆ 1934-01-01   ┆ 2023-12-27   ┆ 51.1278  ┆ 13.7543   ┆ 228.0  ┆ Dresden-Klo ┆ Sachsen │
# │            ┆ 00:00:00 UTC ┆ 00:00:00 UTC ┆          ┆           ┆        ┆ tzsche      ┆         │
# └────────────┴──────────────┴──────────────┴──────────┴───────────┴────────┴─────────────┴─────────┘

# %%
request.filter_by_name("Dresden Klo", threshold=70).df
# Out:
# shape: (3, 8)
# ┌────────────┬──────────────┬──────────────┬──────────┬───────────┬────────┬─────────────┬─────────┐
# │ station_id ┆ start_date   ┆ end_date     ┆ latitude ┆ longitude ┆ height ┆ name        ┆ state   │
# │ ---        ┆ ---          ┆ ---          ┆ ---      ┆ ---       ┆ ---    ┆ ---         ┆ ---     │
# │ str        ┆ datetime[μs, ┆ datetime[μs, ┆ f64      ┆ f64       ┆ f64    ┆ str         ┆ str     │
# │            ┆ UTC]         ┆ UTC]         ┆          ┆           ┆        ┆             ┆         │
# ╞════════════╪══════════════╪══════════════╪══════════╪═══════════╪════════╪═════════════╪═════════╡
# │ 01047      ┆ 1828-01-01   ┆ 1915-12-31   ┆ 51.0557  ┆ 13.7274   ┆ 112.0  ┆ Dresden     ┆ Sachsen │
# │            ┆ 00:00:00 UTC ┆ 00:00:00 UTC ┆          ┆           ┆        ┆ (Mitte)     ┆         │
# │ 01048      ┆ 1934-01-01   ┆ 2023-12-27   ┆ 51.1278  ┆ 13.7543   ┆ 228.0  ┆ Dresden-Klo ┆ Sachsen │
# │            ┆ 00:00:00 UTC ┆ 00:00:00 UTC ┆          ┆           ┆        ┆ tzsche      ┆         │
# │ 05282      ┆ 1917-01-01   ┆ 1974-06-30   ┆ 51.1197  ┆ 13.6744   ┆ 246.0  ┆ Wahnsdorf   ┆ Sachsen │
# │            ┆ 00:00:00 UTC ┆ 00:00:00 UTC ┆          ┆           ┆        ┆ bei Dresden ┆         │
# └────────────┴──────────────┴──────────────┴──────────┴───────────┴────────┴─────────────┴─────────┘

# %%
request.filter_by_sql("SELECT * FROM df WHERE name LIKE 'Dresden%' AND ABS(height - 200) < 30").df
# Out:
# shape: (1, 8)
# ┌────────────┬──────────────┬──────────────┬──────────┬───────────┬────────┬─────────────┬─────────┐
# │ station_id ┆ start_date   ┆ end_date     ┆ latitude ┆ longitude ┆ height ┆ name        ┆ state   │
# │ ---        ┆ ---          ┆ ---          ┆ ---      ┆ ---       ┆ ---    ┆ ---         ┆ ---     │
# │ str        ┆ datetime[μs, ┆ datetime[μs, ┆ f64      ┆ f64       ┆ f64    ┆ str         ┆ str     │
# │            ┆ UTC]         ┆ UTC]         ┆          ┆           ┆        ┆             ┆         │
# ╞════════════╪══════════════╪══════════════╪══════════╪═══════════╪════════╪═════════════╪═════════╡
# │ 01048      ┆ 1934-01-01   ┆ 2023-12-27   ┆ 51.1278  ┆ 13.7543   ┆ 228.0  ┆ Dresden-Klo ┆ Sachsen │
# │            ┆ 00:00:00 UTC ┆ 00:00:00 UTC ┆          ┆           ┆        ┆ tzsche      ┆         │
# └────────────┴──────────────┴──────────────┴──────────┴───────────┴────────┴─────────────┴─────────┘

# %%
request.filter_by_bbox(left=13.74, bottom=51.126, right=13.755, top=51.13).df
# Out:
# shape: (1, 8)
# ┌────────────┬──────────────┬──────────────┬──────────┬───────────┬────────┬─────────────┬─────────┐
# │ station_id ┆ start_date   ┆ end_date     ┆ latitude ┆ longitude ┆ height ┆ name        ┆ state   │
# │ ---        ┆ ---          ┆ ---          ┆ ---      ┆ ---       ┆ ---    ┆ ---         ┆ ---     │
# │ str        ┆ datetime[μs, ┆ datetime[μs, ┆ f64      ┆ f64       ┆ f64    ┆ str         ┆ str     │
# │            ┆ UTC]         ┆ UTC]         ┆          ┆           ┆        ┆             ┆         │
# ╞════════════╪══════════════╪══════════════╪══════════╪═══════════╪════════╪═════════════╪═════════╡
# │ 01048      ┆ 1934-01-01   ┆ 2023-12-27   ┆ 51.1278  ┆ 13.7543   ┆ 228.0  ┆ Dresden-Klo ┆ Sachsen │
# │            ┆ 00:00:00 UTC ┆ 00:00:00 UTC ┆          ┆           ┆        ┆ tzsche      ┆         │
# └────────────┴──────────────┴──────────────┴──────────┴───────────┴────────┴─────────────┴─────────┘

# %% [markdown]
# ## Summarize values
# Fill up values from nearby stations

# %%
request.summarize((51.05089, 13.73832)).df
# Out:
# shape: (14_611, 6)
# ┌────────────┬───────────────────────┬──────────────────────┬────────┬──────────┬──────────────────┐
# │ station_id ┆ parameter             ┆ date                 ┆ value  ┆ distance ┆ taken_station_id │
# │ ---        ┆ ---                   ┆ ---                  ┆ ---    ┆ ---      ┆ ---              │
# │ str        ┆ str                   ┆ datetime[μs, UTC]    ┆ f64    ┆ f64      ┆ str              │
# ╞════════════╪═══════════════════════╪══════════════════════╪════════╪══════════╪══════════════════╡
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1930-01-01 00:00:00  ┆ 275.75 ┆ 8.86     ┆ 05282            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1930-01-02 00:00:00  ┆ 278.25 ┆ 8.86     ┆ 05282            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1930-01-03 00:00:00  ┆ 279.35 ┆ 8.86     ┆ 05282            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1930-01-04 00:00:00  ┆ 279.25 ┆ 8.86     ┆ 05282            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ …          ┆ …                     ┆ …                    ┆ …      ┆ …        ┆ …                │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1969-12-29 00:00:00  ┆ 262.95 ┆ 3.86     ┆ 01051            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1969-12-30 00:00:00  ┆ 267.55 ┆ 3.86     ┆ 01051            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1969-12-31 00:00:00  ┆ 263.35 ┆ 3.86     ┆ 01051            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# │ 00d676be   ┆ temperature_air_mean_ ┆ 1970-01-01 00:00:00  ┆ 262.65 ┆ 3.86     ┆ 01051            │
# │            ┆ 200                   ┆ UTC                  ┆        ┆          ┆                  │
# └────────────┴───────────────────────┴──────────────────────┴────────┴──────────┴──────────────────┘

# %% [markdown]
# ## Interpolate values

# %%
request.interpolate((51.05089, 13.73832)).df
# Out:
# shape: (14_611, 6)
# ┌────────────┬────────────────────┬───────────────────┬────────┬───────────────┬───────────────────┐
# │ station_id ┆ parameter          ┆ date              ┆ value  ┆ distance_mean ┆ taken_station_ids │
# │ ---        ┆ ---                ┆ ---               ┆ ---    ┆ ---           ┆ ---               │
# │ str        ┆ str                ┆ datetime[μs, UTC] ┆ f64    ┆ f64           ┆ list[str]         │
# ╞════════════╪════════════════════╪═══════════════════╪════════╪═══════════════╪═══════════════════╡
# │ af144e51   ┆ temperature_air_me ┆ 1930-01-01        ┆ null   ┆ null          ┆ []                │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆                   │
# │ af144e51   ┆ temperature_air_me ┆ 1930-01-02        ┆ null   ┆ null          ┆ []                │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆                   │
# │ af144e51   ┆ temperature_air_me ┆ 1930-01-03        ┆ null   ┆ null          ┆ []                │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆                   │
# │ af144e51   ┆ temperature_air_me ┆ 1930-01-04        ┆ null   ┆ null          ┆ []                │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆                   │
# │ …          ┆ …                  ┆ …                 ┆ …      ┆ …             ┆ …                 │
# │ af144e51   ┆ temperature_air_me ┆ 1969-12-29        ┆ 262.25 ┆ 9.09          ┆ ["01051",         │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆ "01050", …        │
# │            ┆                    ┆                   ┆        ┆               ┆ "00991"]          │
# │ af144e51   ┆ temperature_air_me ┆ 1969-12-30        ┆ 266.12 ┆ 9.09          ┆ ["01051",         │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆ "01050", …        │
# │            ┆                    ┆                   ┆        ┆               ┆ "00991"]          │
# │ af144e51   ┆ temperature_air_me ┆ 1969-12-31        ┆ 262.22 ┆ 9.09          ┆ ["01051",         │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆ "01050", …        │
# │            ┆                    ┆                   ┆        ┆               ┆ "00991"]          │
# │ af144e51   ┆ temperature_air_me ┆ 1970-01-01        ┆ 261.24 ┆ 9.09          ┆ ["01051",         │
# │            ┆ an_200             ┆ 00:00:00 UTC      ┆        ┆               ┆ "01050", …        │
# │            ┆                    ┆                   ┆        ┆               ┆ "00991"]          │
# └────────────┴────────────────────┴───────────────────┴────────┴───────────────┴───────────────────┘
